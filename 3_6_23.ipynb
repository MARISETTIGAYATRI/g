# %% [markdown]
# <a href="https://colab.research.google.com/github/MARISETTIGAYATRI/g/blob/main/3_6_23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
df= pd.read_csv('/content/xAPI-Edu-Data.csv')

# %%
import numpy as np
import pandas as pd
df= pd.read_csv('/content/xAPI-Edu-Data.csv')
df
# Out:
#     gender NationalITy PlaceofBirth       StageID GradeID SectionID  \
# 0        M          KW       KuwaIT    lowerlevel    G-04         A
# 1        M          KW       KuwaIT    lowerlevel    G-04         A
# 2        M          KW       KuwaIT    lowerlevel    G-04         A
# 3        M          KW       KuwaIT    lowerlevel    G-04         A
# 4        M          KW       KuwaIT    lowerlevel    G-04         A
# ..     ...         ...          ...           ...     ...       ...
# 475      F      Jordan       Jordan  MiddleSchool    G-08         A
# 476      F      Jordan       Jordan  MiddleSchool    G-08         A
# 477      F      Jordan       Jordan  MiddleSchool    G-08         A
# 478      F      Jordan       Jordan  MiddleSchool    G-08         A
# 479      F      Jordan       Jordan  MiddleSchool    G-08         A
#
#          Topic Semester Relation  raisedhands  VisITedResources  \
# 0           IT        F   Father           15                16
# ...

# %%
df=pd.read_csv('/content/xAPI-Edu-Data.csv',header=[0,1,2])
df
# Out:
#     gender NationalITy PlaceofBirth       StageID GradeID SectionID  \
#          M          KW       KuwaIT    lowerlevel    G-04         A
#          M          KW       KuwaIT    lowerlevel    G-04         A
# 0        M          KW       KuwaIT    lowerlevel    G-04         A
# 1        M          KW       KuwaIT    lowerlevel    G-04         A
# 2        M          KW       KuwaIT    lowerlevel    G-04         A
# 3        F          KW       KuwaIT    lowerlevel    G-04         A
# 4        M          KW       KuwaIT  MiddleSchool    G-07         A
# ..     ...         ...          ...           ...     ...       ...
# 473      F      Jordan       Jordan  MiddleSchool    G-08         A
# 474      F      Jordan       Jordan  MiddleSchool    G-08         A
# 475      F      Jordan       Jordan  MiddleSchool    G-08         A
# 476      F      Jordan       Jordan  MiddleSchool    G-08         A
# 477      F      Jordan       Jordan  MiddleSchool    G-08         A
#
# ...

# %%
df.shape
# Out:
# (478, 17)

# %%
df.head(10)
# Out:
#   gender NationalITy PlaceofBirth       StageID GradeID SectionID Topic  \
#        M          KW       KuwaIT    lowerlevel    G-04         A    IT
#        M          KW       KuwaIT    lowerlevel    G-04         A    IT
# 0      M          KW       KuwaIT    lowerlevel    G-04         A    IT
# 1      M          KW       KuwaIT    lowerlevel    G-04         A    IT
# 2      M          KW       KuwaIT    lowerlevel    G-04         A    IT
# 3      F          KW       KuwaIT    lowerlevel    G-04         A    IT
# 4      M          KW       KuwaIT  MiddleSchool    G-07         A  Math
# 5      M          KW       KuwaIT  MiddleSchool    G-07         A  Math
# 6      F          KW       KuwaIT  MiddleSchool    G-07         A  Math
# 7      F          KW       KuwaIT  MiddleSchool    G-07         B    IT
# 8      M          KW       KuwaIT  MiddleSchool    G-07         A  Math
# 9      M          KW       KuwaIT  MiddleSchool    G-07         B  Math
#
# ...

# %%
df.tail(10)
# Out:
#     gender NationalITy PlaceofBirth       StageID GradeID SectionID  \
#          M          KW       KuwaIT    lowerlevel    G-04         A
#          M          KW       KuwaIT    lowerlevel    G-04         A
# 468      M   Palestine       Jordan  MiddleSchool    G-08         A
# 469      M   Palestine       Jordan  MiddleSchool    G-08         A
# 470      M   Palestine    Palestine  MiddleSchool    G-08         A
# 471      M   Palestine    Palestine  MiddleSchool    G-08         A
# 472      F      Jordan       Jordan  MiddleSchool    G-08         A
# 473      F      Jordan       Jordan  MiddleSchool    G-08         A
# 474      F      Jordan       Jordan  MiddleSchool    G-08         A
# 475      F      Jordan       Jordan  MiddleSchool    G-08         A
# 476      F      Jordan       Jordan  MiddleSchool    G-08         A
# 477      F      Jordan       Jordan  MiddleSchool    G-08         A
#
#          Topic Semester Relation raisedhands VisITedResources  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 478 entries, 0 to 477
# Data columns (total 17 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   (gender, M, M)                          478 non-null    object
#  1   (NationalITy, KW, KW)                   478 non-null    object
#  2   (PlaceofBirth, KuwaIT, KuwaIT)          478 non-null    object
#  3   (StageID, lowerlevel, lowerlevel)       478 non-null    object
#  4   (GradeID, G-04, G-04)                   478 non-null    object
#  5   (SectionID, A, A)                       478 non-null    object
#  6   (Topic, IT, IT)                         478 non-null    object
#  7   (Semester, F, F)                        478 non-null    object
#  8   (Relation, Father, Father)              478 non-null    object
#  9   (raisedhands, 15, 20)                   478 non-null    int64
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=478, step=1)

# %%
import numpy as np
import pandas as pd
df= pd.read_csv('/content/xAPI-Edu-Data.csv')

# %%
s=pd.read_csv('/content/xAPI-Edu-Data.csv', sep=":", nrows=3)
s
# Out:
#   gender,NationalITy,PlaceofBirth,StageID,GradeID,SectionID,Topic,Semester,Relation,raisedhands,VisITedResources,AnnouncementsView,Discussion,ParentAnsweringSurvey,ParentschoolSatisfaction,StudentAbsenceDays,Class
# 0  M,KW,KuwaIT,lowerlevel,G-04,A,IT,F,Father,15,1...
# 1  M,KW,KuwaIT,lowerlevel,G-04,A,IT,F,Father,20,2...
# 2  M,KW,KuwaIT,lowerlevel,G-04,A,IT,F,Father,10,7...

# %%
g=df.drop
g
# Out:
# <bound method DataFrame.drop of   gender,NationalITy,PlaceofBirth,StageID,GradeID,SectionID,Topic,Semester,Relation,raisedhands,VisITedResources,AnnouncementsView,Discussion,ParentAnsweringSurvey,ParentschoolSatisfaction,StudentAbsenceDays,Class
# 0  M,KW,KuwaIT,lowerlevel,G-04,A,IT,F,Father,15,1...
# 1  M,KW,KuwaIT,lowerlevel,G-04,A,IT,F,Father,20,2...
# 2  M,KW,KuwaIT,lowerlevel,G-04,A,IT,F,Father,10,7...                                                                                                                                                                 >

# %%
df.drop('gender')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-42-cbaa8efe70dd> in <cell line: 1>()
# ----> 1 df.drop('Topic',axis=1)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5397                 weight  1.0     0.8
#    5398         """
# -> 5399         return super().drop(
#    5400             labels=labels,
#    5401             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
# ...

# %%
df
# Out:
#   gender,NationalITy,PlaceofBirth,StageID,GradeID,SectionID,Topic,Semester,Relation,raisedhands,VisITedResources,AnnouncementsView,Discussion,ParentAnsweringSurvey,ParentschoolSatisfaction,StudentAbsenceDays,Class
# 0  M,KW,KuwaIT,lowerlevel,G-04,A,IT,F,Father,15,1...
# 1  M,KW,KuwaIT,lowerlevel,G-04,A,IT,F,Father,20,2...
# 2  M,KW,KuwaIT,lowerlevel,G-04,A,IT,F,Father,10,7...

# %%
df=pd.read_csv('/content/xAPI-Edu-Data.csv')
df
# Out:
#    gender NationalITy PlaceofBirth       StageID GradeID SectionID    Topic  \
# 0       M          KW       KuwaIT    lowerlevel    G-04         A       IT
# 1       M          KW       KuwaIT    lowerlevel    G-04         A       IT
# 2       M          KW       KuwaIT    lowerlevel    G-04         A       IT
# 3       M          KW       KuwaIT    lowerlevel    G-04         A       IT
# 4       M          KW       KuwaIT    lowerlevel    G-04         A       IT
# 5       F          KW       KuwaIT    lowerlevel    G-04         A       IT
# 6       M          KW       KuwaIT  MiddleSchool    G-07         A     Math
# 7       M          KW       KuwaIT  MiddleSchool    G-07         A     Math
# 8       F          KW       KuwaIT  MiddleSchool    G-07         A     Math
# 9       F          KW       KuwaIT  MiddleSchool    G-07         B       IT
# 10      M          KW       KuwaIT  MiddleSchool    G-07         A     Math
# ...

# %%
avg_age=df['raisedhands'].mean()
print("Average age is:",avg_age)
# Out:
# Average age is: 32.89655172413793

# %%
df.drop(labels=range(5,25),axis=0)
# Out:
#    gender NationalITy PlaceofBirth       StageID GradeID SectionID    Topic  \
# 0       M          KW       KuwaIT    lowerlevel    G-04         A       IT
# 1       M          KW       KuwaIT    lowerlevel    G-04         A       IT
# 2       M          KW       KuwaIT    lowerlevel    G-04         A       IT
# 3       M          KW       KuwaIT    lowerlevel    G-04         A       IT
# 4       M          KW       KuwaIT    lowerlevel    G-04         A       IT
# 25      M          KW       KuwaIT  MiddleSchool    G-07         A       IT
# 26      M          KW       KuwaIT  MiddleSchool    G-07         B       IT
# 27      M          KW       KuwaIT  MiddleSchool    G-08         A   Arabic
# 28      M          KW       KuwaIT  MiddleSchool    G-08         A  Science
#
#    Semester Relation  raisedhands  VisITedResources  AnnouncementsView  \
# 0         F   Father           15                16                  2
# ...

# %%
print(df['raisedhands'].max())
# Out:
# 75

# %%
print(df['raisedhands'].min())
# Out:
# 0

# %%
print(df['raisedhands'].mean())
# Out:
# 32.89655172413793

# %%
df.describe()
# Out:
#        raisedhands  VisITedResources  AnnouncementsView  Discussion
# count    29.000000         29.000000          29.000000   29.000000
# mean     32.896552         28.241379          17.655172   53.034483
# std      23.138318         26.053044          14.950575   27.898391
# min       0.000000          0.000000           0.000000   11.000000
# 25%      15.000000         12.000000           3.000000   30.000000
# 50%      30.000000         19.000000          15.000000   50.000000
# 75%      50.000000         40.000000          30.000000   80.000000
# max      75.000000         88.000000          52.000000   99.000000

# %%
df=pd.read_csv('/content/xAPI-Edu-Data.csv')
print(df)
# Out:
#    gender NationalITy PlaceofBirth       StageID GradeID SectionID    Topic  \
# 0       M          KW       KuwaIT    lowerlevel    G-04         A       IT
# 1       M          KW       KuwaIT    lowerlevel    G-04         A       IT
# 2       M          KW       KuwaIT    lowerlevel    G-04         A       IT
# 3       M          KW       KuwaIT    lowerlevel    G-04         A       IT
# 4       M          KW       KuwaIT    lowerlevel    G-04         A       IT
# 5       F          KW       KuwaIT    lowerlevel    G-04         A       IT
# 6       M          KW       KuwaIT  MiddleSchool    G-07         A     Math
# 7       M          KW       KuwaIT  MiddleSchool    G-07         A     Math
# 8       F          KW       KuwaIT  MiddleSchool    G-07         A     Math
# 9       F          KW       KuwaIT  MiddleSchool    G-07         B       IT
# 10      M          KW       KuwaIT  MiddleSchool    G-07         A     Math
# ...

# %%
df.drop(df[df['raisedhands']<=17].index)
# Out:
#    gender NationalITy PlaceofBirth       StageID GradeID SectionID    Topic  \
# 1       M          KW       KuwaIT    lowerlevel    G-04         A       IT
# 3       M          KW       KuwaIT    lowerlevel    G-04         A       IT
# 4       M          KW       KuwaIT    lowerlevel    G-04         A       IT
# 5       F          KW       KuwaIT    lowerlevel    G-04         A       IT
# 6       M          KW       KuwaIT  MiddleSchool    G-07         A     Math
# 7       M          KW       KuwaIT  MiddleSchool    G-07         A     Math
# 9       F          KW       KuwaIT  MiddleSchool    G-07         B       IT
# 10      M          KW       KuwaIT  MiddleSchool    G-07         A     Math
# 11      M          KW       KuwaIT  MiddleSchool    G-07         B     Math
# 13      M     lebanon      lebanon  MiddleSchool    G-08         A     Math
# 14      F          KW       KuwaIT  MiddleSchool    G-08         A     Math
# ...

# %%
df.drop(columns=df.select_dtypes(include=int).columns)
# Out:
#    gender NationalITy PlaceofBirth       StageID GradeID SectionID    Topic  \
# 0       M          KW       KuwaIT    lowerlevel    G-04         A       IT
# 1       M          KW       KuwaIT    lowerlevel    G-04         A       IT
# 2       M          KW       KuwaIT    lowerlevel    G-04         A       IT
# 3       M          KW       KuwaIT    lowerlevel    G-04         A       IT
# 4       M          KW       KuwaIT    lowerlevel    G-04         A       IT
# 5       F          KW       KuwaIT    lowerlevel    G-04         A       IT
# 6       M          KW       KuwaIT  MiddleSchool    G-07         A     Math
# 7       M          KW       KuwaIT  MiddleSchool    G-07         A     Math
# 8       F          KW       KuwaIT  MiddleSchool    G-07         A     Math
# 9       F          KW       KuwaIT  MiddleSchool    G-07         B       IT
# 10      M          KW       KuwaIT  MiddleSchool    G-07         A     Math
# ...

# %%
print(df)
# Out:
#    gender NationalITy PlaceofBirth       StageID GradeID SectionID    Topic  \
# 0       M          KW       KuwaIT    lowerlevel    G-04         A       IT
# 1       M          KW       KuwaIT    lowerlevel    G-04         A       IT
# 2       M          KW       KuwaIT    lowerlevel    G-04         A       IT
# 3       M          KW       KuwaIT    lowerlevel    G-04         A       IT
# 4       M          KW       KuwaIT    lowerlevel    G-04         A       IT
# 5       F          KW       KuwaIT    lowerlevel    G-04         A       IT
# 6       M          KW       KuwaIT  MiddleSchool    G-07         A     Math
# 7       M          KW       KuwaIT  MiddleSchool    G-07         A     Math
# 8       F          KW       KuwaIT  MiddleSchool    G-07         A     Math
# 9       F          KW       KuwaIT  MiddleSchool    G-07         B       IT
# 10      M          KW       KuwaIT  MiddleSchool    G-07         A     Math
# ...

# %%
df['Height_rank']=df['raisedhands'].rank()
df.set_index('Height_rank')
print(df)
# Out:
#    gender NationalITy PlaceofBirth       StageID GradeID SectionID    Topic  \
# 0       M          KW       KuwaIT    lowerlevel    G-04         A       IT
# 1       M          KW       KuwaIT    lowerlevel    G-04         A       IT
# 2       M          KW       KuwaIT    lowerlevel    G-04         A       IT
# 3       M          KW       KuwaIT    lowerlevel    G-04         A       IT
# 4       M          KW       KuwaIT    lowerlevel    G-04         A       IT
# 5       F          KW       KuwaIT    lowerlevel    G-04         A       IT
# 6       M          KW       KuwaIT  MiddleSchool    G-07         A     Math
# 7       M          KW       KuwaIT  MiddleSchool    G-07         A     Math
# 8       F          KW       KuwaIT  MiddleSchool    G-07         A     Math
# 9       F          KW       KuwaIT  MiddleSchool    G-07         B       IT
# 10      M          KW       KuwaIT  MiddleSchool    G-07         A     Math
# ...

# %%
df.sort_index()
print(df)
# Out:
#    gender NationalITy PlaceofBirth       StageID GradeID SectionID    Topic  \
# 0       M          KW       KuwaIT    lowerlevel    G-04         A       IT
# 1       M          KW       KuwaIT    lowerlevel    G-04         A       IT
# 2       M          KW       KuwaIT    lowerlevel    G-04         A       IT
# 3       M          KW       KuwaIT    lowerlevel    G-04         A       IT
# 4       M          KW       KuwaIT    lowerlevel    G-04         A       IT
# 5       F          KW       KuwaIT    lowerlevel    G-04         A       IT
# 6       M          KW       KuwaIT  MiddleSchool    G-07         A     Math
# 7       M          KW       KuwaIT  MiddleSchool    G-07         A     Math
# 8       F          KW       KuwaIT  MiddleSchool    G-07         A     Math
# 9       F          KW       KuwaIT  MiddleSchool    G-07         B       IT
# 10      M          KW       KuwaIT  MiddleSchool    G-07         A     Math
# ...

# %%
df.drop(labels='Height_rank',axis=1)
# Out:
#    gender NationalITy PlaceofBirth       StageID GradeID SectionID    Topic  \
# 0       M          KW       KuwaIT    lowerlevel    G-04         A       IT
# 1       M          KW       KuwaIT    lowerlevel    G-04         A       IT
# 2       M          KW       KuwaIT    lowerlevel    G-04         A       IT
# 3       M          KW       KuwaIT    lowerlevel    G-04         A       IT
# 4       M          KW       KuwaIT    lowerlevel    G-04         A       IT
# 5       F          KW       KuwaIT    lowerlevel    G-04         A       IT
# 6       M          KW       KuwaIT  MiddleSchool    G-07         A     Math
# 7       M          KW       KuwaIT  MiddleSchool    G-07         A     Math
# 8       F          KW       KuwaIT  MiddleSchool    G-07         A     Math
# 9       F          KW       KuwaIT  MiddleSchool    G-07         B       IT
# 10      M          KW       KuwaIT  MiddleSchool    G-07         A     Math
# ...

# %%
df.sort_values(by="raisedhands")
# Out:
#    gender NationalITy PlaceofBirth       StageID GradeID SectionID    Topic  \
# 24      M          KW       KuwaIT  MiddleSchool    G-07         B       IT
# 23      M          KW       KuwaIT  MiddleSchool    G-07         A       IT
# 12      M          KW       KuwaIT    lowerlevel    G-04         A       IT
# 25      M          KW       KuwaIT  MiddleSchool    G-07         A       IT
# 21      F          KW       KuwaIT  MiddleSchool    G-07         B       IT
# 2       M          KW       KuwaIT    lowerlevel    G-04         A       IT
# 8       F          KW       KuwaIT  MiddleSchool    G-07         A     Math
# 22      M          KW       KuwaIT  MiddleSchool    G-07         A       IT
# 0       M          KW       KuwaIT    lowerlevel    G-04         A       IT
# 26      M          KW       KuwaIT  MiddleSchool    G-07         B       IT
# 11      M          KW       KuwaIT  MiddleSchool    G-07         B     Math
# ...

# %%
print(df['raisedhands'].mean())
print(df['raisedhands'].max())
print(df['raisedhands'].median())
print(df['raisedhands'].mode())
print(df['raisedhands'].std())
print(df['raisedhands'].var())
print(df['raisedhands'].count())
# Out:
# 32.89655172413793
# 75
# 30.0
# 0    10
# 1    15
# 2    19
# 3    20
# 4    30
# 5    50
# 6    70
# Name: raisedhands, dtype: int64
# 23.1383182923698
# 535.3817733990148
# 29

# %%
df=df.dropna()

# %%
df['raisedhands'].unique()
# Out:
# array([15, 20, 10, 30, 40, 42, 35, 50, 12, 70, 19,  5, 62, 36, 55, 69, 60,
#         2,  0,  8, 25, 75])

# %%
df['raisedhands'].count()
# Out:
# 29
